# %%
# !pip install requests
# Out:
# Requirement already satisfied: requests in c:\users\client\downloads\code\hackathon\venv_sourcing\lib\site-packages (2.32.5)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\client\downloads\code\hackathon\venv_sourcing\lib\site-packages (from requests) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\client\downloads\code\hackathon\venv_sourcing\lib\site-packages (from requests) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\client\downloads\code\hackathon\venv_sourcing\lib\site-packages (from requests) (2.6.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\client\downloads\code\hackathon\venv_sourcing\lib\site-packages (from requests) (2025.11.12)
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import requests
import json
from pathlib import Path

API_BASE_URL = "http://localhost:9200"
INGEST_ENDPOINT = f"{API_BASE_URL}/ingest"

# Load and test with just one candidate
data_dir = Path("../data")
sample_file = data_dir / "sample_candidates.json"


if sample_file.exists():
    with open(sample_file, 'r', encoding='utf-8') as f:
        candidates = json.load(f)
    
    # Test with first candidate only
    #print(f"Testing with 1 candidate (ID: {test_candidate[0].get('candidateId', 'N/A')})")
    #print(f"Sample structure - resumeData keys: {list(test_candidate[0].get('resumeData', {}).keys())}")
        
    for ix, candidate in enumerate(candidates[:1]):
        test_candidate = candidate
        if ix//10 == 0:
            print(f"Processing candidate {ix} of {len(candidates)}")
        try:
            response = requests.post(
                INGEST_ENDPOINT,
                json=test_candidate,
                params={"collection_name": "candidates_store"},
                headers={"Content-Type": "application/json"},
                timeout=60
            )
            
            response.raise_for_status()
            result = response.json()
            print(f"\n✓ Success! Test candidate ingested.")

            print(f"Result: {json.dumps(result, indent=2)}")
            
        except requests.exceptions.RequestException as e:
            print(f"\n✗ Error: {e}")
            if hasattr(e, 'response') and e.response is not None:
                print(f"Status: {e.response.status_code}")
                try:
                    error = e.response.json()
                    print(f"Error: {json.dumps(error, indent=2)}")
                except:
                    print(f"Response: {e.response.text}")
else:
    print("Sample file not found")
# Out:
# Processing candidate 0 of 100
#
# ✓ Success! Test candidate ingested.
# Result: {
#   "status": "accepted",
#   "message": "Ingestion started in background for 1 candidates",
#   "collection_name": "candidates_store",
#   "total_candidates": 1,
#   "note": "Check logs for final results and detailed progress"
# }

# %%
import requests
import json
from pathlib import Path

API_BASE_URL = "http://localhost:9100"
INGEST_ENDPOINT = f"{API_BASE_URL}/ingest"

# Load and test with all candidates in array
data_dir = Path("../data")
# sample_file = data_dir / "sample_candidates.json"
sample_file = data_dir / "candidates_1000.json"

if sample_file.exists():
    with open(sample_file, 'r', encoding='utf-8') as f:
        candidates = json.load(f)
    
    print(f"Testing with {len(candidates)} candidates")
    if candidates:
        print(f"First candidate ID: {candidates[0].get('candidateId', 'N/A')}")
        print(f"Sample structure - resumeData keys: {list(candidates[0].get('resumeData', {}).keys())}")
    
    try:
        response = requests.post(
            INGEST_ENDPOINT,
            json=candidates,
            params={"collection_name": "candidates_store"},
            headers={"Content-Type": "application/json"},
            timeout=60
        )
        
        response.raise_for_status()
        result = response.json()
        print(f"\n✓ Success! {len(candidates)} candidates ingested.")

        print(f"Result: {json.dumps(result, indent=2)}")
        
    except requests.exceptions.RequestException as e:
        print(f"\n✗ Error: {e}")
        if hasattr(e, 'response') and e.response is not None:
            print(f"Status: {e.response.status_code}")
            try:
                error = e.response.json()
                print(f"Error: {json.dumps(error, indent=2)}")
            except:
                print(f"Response: {e.response.text}")
else:
    print("Sample file not found")
# Out:
# Testing with 1000 candidates
# First candidate ID: 8284346
# Sample structure - resumeData keys: ['ContactInformation', 'ProfessionalSummary', 'Objective', 'CoverLetter', 'PersonalAttributes', 'Education', 'EmploymentHistory', 'SkillsData', 'Skills', 'Certifications', 'Licenses', 'Associations', 'LanguageCompetencies', 'MilitaryExperience', 'SecurityCredentials', 'References', 'Achievements', 'Training', 'QualificationsSummary', 'Hobbies', 'Patents', 'Publications', 'SpeakingEngagements', 'ResumeMetadata', 'UserDefinedTags']
#
# ✗ Error: HTTPConnectionPool(host='localhost', port=9100): Read timed out. (read timeout=60)

# %%
import requests
import json

API_BASE_URL = "http://localhost:9100"
GET_COLLECTION_INFO_ENDPOINT = f"{API_BASE_URL}/collections/candidates_store"

try:
    response = requests.get(
        GET_COLLECTION_INFO_ENDPOINT,
        headers={"Content-Type": "application/json"},
        timeout=30
    )
    response.raise_for_status()
    result = response.json()
    print("✓ Success! Collection info fetched.")
    print(f"Result: {json.dumps(result, indent=2)}")
except requests.exceptions.RequestException as e:
    print(f"\n✗ Error: {e}")
    if hasattr(e, 'response') and e.response is not None:
        print(f"Status: {e.response.status_code}")
        try:
            error = e.response.json()
            print(f"Error: {json.dumps(error, indent=2)}")
        except:
            print(f"Response: {e.response.text}")

# %%
filter = result['candidate_ids']

# %%
for c in candidates[:5]:
    print(c['candidateId'])
# Out:
# 8284346
# 8566860
# 5692722
# 8566304
# 5866975

# %%
API_BASE_URL = "http://localhost:9100"
INGEST_ENDPOINT = f"{API_BASE_URL}/ingest"

new_candidates = []
for candidate in candidates:
    if candidate['candidateId'] not in filter:
        new_candidates.append(candidate)

print(len(new_candidates))

try:
    response = requests.post(
        INGEST_ENDPOINT,
        json=new_candidates,
        params={"collection_name": "candidates_store"},
        headers={"Content-Type": "application/json"},
        timeout=60
    )
    
    response.raise_for_status()
    result = response.json()
    print(f"\n✓ Success! {len(candidates)} candidates ingested.")

    print(f"Result: {json.dumps(result, indent=2)}")
    
except requests.exceptions.RequestException as e:
    print(f"\n✗ Error: {e}")
    if hasattr(e, 'response') and e.response is not None:
        print(f"Status: {e.response.status_code}")
        try:
            error = e.response.json()
            print(f"Error: {json.dumps(error, indent=2)}")
        except:
            print(f"Response: {e.response.text}")
# Out:
# 0
#
# ✗ Error: 400 Client Error: Bad Request for url: http://localhost:9100/ingest?collection_name=candidates_store
# Status: 400
# Error: {
#   "detail": "No candidates provided"
# }

# %%
data_dir = Path("../data")
sample_file = data_dir / "final_data.json"
if sample_file.exists():
    with open(sample_file, 'r', encoding='utf-8') as f:
        all_candidates = json.load(f)

# %%
len(all_candidates)
# Out:
# 99996

# %%
API_BASE_URL = "http://localhost:9200"
INGEST_ENDPOINT = f"{API_BASE_URL}/ingest"

response = requests.post(
            INGEST_ENDPOINT,
            json=candidates[0],
            params={"collection_name": "candidates_store"},
            headers={"Content-Type": "application/json"},
            timeout=60
        )

# %%
API_BASE_URL = "http://localhost:9200"
INGEST_ENDPOINT = f"{API_BASE_URL}/ingest"
candidates = all_candidates[:1000]
if True:
    print(f"Testing with {len(candidates)} candidates")
    if candidates:
        print(f"First candidate ID: {candidates[0].get('candidateId', 'N/A')}")
        print(f"Sample structure - resumeData keys: {list(candidates[0].get('resumeData', {}).keys())}")
    
    try:
        response = requests.post(
            INGEST_ENDPOINT,
            json=upsert_cand_obj,
            params={"collection_name": "candidates_store"},
            headers={"Content-Type": "application/json"},
            timeout=60
        )
        
        response.raise_for_status()
        result = response.json()
        print(f"\n✓ Success! {len(candidates)} candidates ingested.")

        print(f"Result: {json.dumps(result, indent=2)}")
        
    except requests.exceptions.RequestException as e:
        print(f"\n✗ Error: {e}")
        if hasattr(e, 'response') and e.response is not None:
            print(f"Status: {e.response.status_code}")
            try:
                error = e.response.json()
                print(f"Error: {json.dumps(error, indent=2)}")
            except:
                print(f"Response: {e.response.text}")
else:
    print("Sample file not found")
# Out:
# Testing with 1000 candidates
# First candidate ID: N/A
# Sample structure - resumeData keys: []
#
# ✓ Success! 1000 candidates ingested.
# Result: {
#   "total": 14,
#   "successful": 4,
#   "failed": 10,
#   "results": [
#     {
#       "candidate_id": "2046354350783",
#       "success": false,
#       "vector_id": null,
#       "error": "Candidate already exists in collection (omit mode)"
#     },
#     {
#       "candidate_id": "12572869158483",
#       "success": false,
#       "vector_id": null,
#       "error": "Candidate already exists in collection (omit mode)"
#     },
#     {
#       "candidate_id": "13777220638865",
#       "success": false,
#       "vector_id": null,
#       "error": "Candidate already exists in collection (omit mode)"
#     },
#     {
#       "candidate_id": "16460284648083",
#       "success": false,
#       "vector_id": null,
#       "error": "Candidate already exists in collection (omit mode)"
#     },
#     {
#       "candidate_id": "17301398855299",
#       "success": false,
#       "vector_id": null,
#       "error": "Candidate already exists in collection (omit mode)"
#     },
#     {
#       "candidate_id": "17618576578285",
#       "success": false,
#       "vector_id": null,
#       "error": "Candidate already exists in collection (omit mode)"
#     },
#     {
#       "candidate_id": "18114147674562",
#       "success": false,
#       "vector_id": null,
#       "error": "Candidate already exists in collection (omit mode)"
#     },
#     {
#       "candidate_id": "18121606064589",
#       "success": false,
#       "vector_id": null,
#       "error": "Candidate already exists in collection (omit mode)"
#     },
#     {
#       "candidate_id": "18161309884041",
#       "success": false,
#       "vector_id": null,
#       "error": "Candidate already exists in collection (omit mode)"
#     },
#     {
#       "candidate_id": "18467450198989",
#       "success": false,
#       "vector_id": null,
#       "error": "Candidate already exists in collection (omit mode)"
#     },
#     {
#       "candidate_id": "16480193363379",
#       "success": true,
#       "vector_id": "0b0c3d54-d1d5-4402-a9c6-47644f59823a",
#       "error": null
#     },
#     {
#       "candidate_id": "17754887086885",
#       "success": true,
#       "vector_id": "b21f2cb9-4d3d-4b79-9c49-70e1bcf85a3e",
#       "error": null
#     },
#     {
#       "candidate_id": "14657248940043",
#       "success": true,
#       "vector_id": "c8e32c7c-26d3-40d9-a010-9e1a39dc3581",
#       "error": null
#     },
#     {
#       "candidate_id": "18459439582599",
#       "success": true,
#       "vector_id": "064b49b6-322c-48c5-a8fb-6e803f49e0e9",
#       "error": null
#     }
#   ]
# }

# %%
jobs_candidates = data_dir / "filtered_candidates.json"
if jobs_candidates.exists():
    with open(jobs_candidates, 'r', encoding='utf-8') as f:
        jobs_candidates = json.load(f)

# %%
upsert_cand = set()
for cand in jobs_candidates:
    upsert_cand.add(cand['ats_candidate_id'])

# %%
upsert_cand_obj = [can for can in all_candidates if can['candidate_id'] in upsert_cand]

# %%
# Out:
# [{'candidate_id': '2046354350783',
#   'client_id': None,
#   'email': 'tarasavino@yahoo.com',
#   'first_name': 'Tamara Dawn',
#   'last_name': 'Savino',
#   'primary_role_code': None,
#   'current_role': None,
#   'skills': [],
#   'country': 'US',
#   'city': 'Atlanta',
#   'address1': '3060 Pharr Court North NW, Unit 822',
#   'address2': '',
#   'workphone': '',
#   'homephone': '',
#   'cellphone': '4045673706',
#   'phone1': '',
#   'phone2': '4045673706',
#   'phone3': '',
#   'phone4': '',
#   'alternateemail': '',
#   'years_experience_total': 28.5,
#   'title_exp': [{'title': 'Artech', 'exp': '07/2024 - 03/2025', 'months': 8},
#    {'title': 'IBM Security Services',
#     'exp': '06/2015 - 03/2025',
#     'months': 117},
#    {'title': 'NextEra Energy. Florida Power Gas & Light / IBM Cybersecurity PM',
#     'exp': '01/2024 - 06/2024',
#     'months': 5},
#    {'title': 'COX Manheim - Technology Solutions, Alpharetta GA',
#     'exp': '03/2014 - 03/2015',
#     'months': 12},
#    {'title': 'McKesson Corporation - Technology Solutions, Alpharetta GA',
#     'exp': '10/2013 - 02/2014',
#     'months': 4},
#    {'title': 'Oversight Systems, Inc. - Marietta, GA',
#     'exp': '03/2013 - 10/2013',
#     'months': 7},
#    {'title': 'SunTrust Bank, Atlanta GA',
#     'exp': '01/2013 - 03/2013',
#     'months': 2},
#    {'title': 'ING Investment Services, Atlanta GA',
#     'exp': '10/2012 - 11/2012',
#     'months': 1},
#    {'title': 'First Data Corporation, Atlanta, GA',
#     'exp': '11/2011 - 06/2012',
#     'months': 7},
#    {'title': 'Georgia Department of Education',
#     'exp': '01/2010 - 06/2011',
#     'months': 17},
#    {'title': 'Matrix Resources', 'exp': '11/2004 - 01/2010', 'months': 62},
#    {'title': 'The Gartner Group and META Security Group, Inc., Atlanta, GA',
#     'exp': '07/1999 - 11/2004',
#     'months': 64},
#    {'title': 'IBM Internet Security Systems th Employee of IBM ISS',
#     'exp': '07/1996 - 07/1999',
#     'months': 36}],
#   'education': [{'SCHOOL': 'Saint Leo University',
#     'MAJOR': 'Saint Leo University',
#     'DEGREE': 'Associate',
#     'YEAR': '2007'}],
#   'resume_data': "    Summary:  Extensive Experience on IBM Sr. Certified / Sr. Security Manager, /Security Solution Architect /IBM Global Security Services (IT Infrastructure) Program leadership professional with extensive experience and SME in Information Systems and Information Security, Risk and Compliance.  Cybersecurity Program Manager with 29 years of overall IT experience, including 19 years in Program & Project Management and 15 years specializing in Cybersecurity Governance, Cloud & Network Defense, and SOC Operations. Proven success leading enterprise-scale security programs across hybrid environments aligned with NIST, ISO 27001, and Zero Trust frameworks. Capabilities include but are not limited to the following: FISCAM, NIST, PCI, ITSM and ITIL, SOX and Governance, Security Transition, Analysis and Expert Technical Writer.    Experience:    Artech July 2024 to March 2025  IBM Security Program Manager for Artech / iBM / AEP client remote Ohio  IAM, NIST, Certified in Workday NIST curriculum, JIRA, SharePoint for PAM and CyberArk Transition .  * Led enterprise-wide Identity and Access Management (IAM) initiatives, overseeing integration of CyberArk and Privileged Access Management (PAM) platforms to strengthen access controls and reduce insider risk.  * Governed security programs aligned with NIST CSF and internal compliance frameworks, ensuring policy adherence and continuous improvement across IT and business domains.  * Managed CyberArk transition program, coordinating between IBM engineering, AEP client security, and vendor partners to streamline PAM onboarding and credential vaulting processes.  * Drove implementation of security governance models, leveraging JIRA and SharePoint for program tracking, KPI management, and risk remediation documentation.  * Collaborated with cloud and infrastructure teams to ensure Zero Trust principles and least privilege access were embedded across hybrid environments.  * Partnered with audit and compliance teams to prepare for NIST-based assessments, supporting documentation, gap analysis, and corrective action plans.  * Facilitated executive-level reporting on IAM, PAM, and governance initiatives, aligning deliverables with strategic cybersecurity and operational resilience goals.  * Championed automation and process improvement within access governance workflows to enhance operational efficiency and reduce manual intervention.    IBM Security Services         06/2015 - March 2025  Sr. Security Manager/Security Solution Architect     IBM Projects:    NextEra Energy. Florida Power Gas & Light / IBM Cybersecurity PM    (Jan 2024 - June 2024 )  * Security Incident Manager for Escalations & Incidents   * Security Ops Focal for Clients   * Highly Proficient in IBM VSOC Portal Liaison between Client & IBM SecOps   * Reports to CISCO at Client Organization doing end-to-end SecurityOps, Incident Management, VSOC & Stakeholder Management  * McAfee ePO Redesign Plan for a $10B World-wide Financial Services Holding Company  * PCI Compliance and Certification & PCI Assessment for an $83B Big-Box Store Global Company   * Large-scale Security Transition Sr. Security PM for a $58B Global Financial Company.   * Client/Customer Relationship, and Finance/HR/ Legal/Account Team Collaboration.  * Steady State Managed Services Solution for a Privately held Fortune 500 Global Financial Company   * Proposal Writer / Reviewer for a $3B Global Parcel & Secure Payments Commerce Company  * Security Tower Transition Project for IBM for a 9.3B Financial/Holding Company  * Data Encryption project for a Privately held 11B Multinational-mass media and information Company  * IBM IDS and QRadar for a $891B Canadian-based Financial Services Company  * ONNET Partner Migration for a $915M Financial Institution  * Security Migration for a $935B Canadian-based Multinational Insurance Company - Indonesia Data Center.   * Experienced industry consultant for legal, finance, insurance, automotive, and manufacturing fo ...
#  {'candidate_id': '12572869158483',
#   'client_id': None,
#   'email': 'karthickksai9@gmail.com',
#   'first_name': 'Karthik',
#   'last_name': 'KA',
#   'primary_role_code': None,
#   'current_role': None,
#   'skills': [],
#   'country': 'US',
#   'city': 'Minneapolis',
#   'address1': '',
#   'address2': '',
#   'workphone': '',
#   'homephone': '',
#   'cellphone': '4696664319',
#   'phone1': '',
#   'phone2': '4696664319',
#   'phone3': '',
#   'phone4': '',
#   'alternateemail': '',
#   'years_experience_total': 8.8,
#   'title_exp': [{'title': 'Role: Sr Java Developer',
#     'exp': '07/2024 - 06/2025',
#     'months': 11},
#    {'title': 'Client : Bank of America Jersey City, USA',
#     'exp': '02/2023 - 06/2024',
#     'months': 16},
#    {'title': 'Client: NCR Coporation, Irving, USA',
#     'exp': '04/2020 - 01/2023',
#     'months': 33},
#    {'title': 'Client: State of California',
#     'exp': '02/2019 - 04/2020',
#     'months': 14},
#    {'title': 'Client: Columbus global India, Hyderabad, India',
#     'exp': '01/2015 - 08/2017',
#     'months': 31}],
#   'education': [{'SCHOOL': 'Concordia University',
#     'MAJOR': 'Information Technology',
#     'DEGREE': 'Master',
#     'YEAR': '0'}],
#   'resume_data': "Name :                                                                     Email:    Title  :   Senior Software  Engineer Mobile: +1(469)-666-4319     Professional Summary Over all 9+ years of extensive development experience, specializing in building n- tier web applications using Java, Python, J2EE, Spring Framework, Spring MVC, Spring Boot,  Hibernate,  and  Web  Services.  My  expertise  spans  various  methodologies, including Waterfall, RUP, Agile (SCRUM, XP), making me a versatile developer.I excel in implementing Service-Oriented Architecture (SOA) through  Microservices, SOAP, RESTful web services, and messaging systems like Apache Kafka. My database prowess extends to  Oracle SQL, PL/SQL, MySQL, and NoSQL databases.  Additionally, I have hands-on experience with cloud platforms like  AWS, Azure  and  GCP covering a wide range of services. I've successfully managed  CI/CD DevOps  processes, using tools like  AWS Code Commit, AWS Code Deploy, Jenkins, and Ansible, while maintaining projects  in  various  version  control  repositories.  I'm  also  well-versed  in containerization technologies like Docker and Kubernetes and have knowledge of IBM Cloud, API connect, and GraphQL, making me a well-rounded developer with a proven track record of delivering robust solutions Technical Skills Languages    : Java 8, 11 and 17, C, C++, Python J2EE Skills    : Servlets, JSP, JDBC, JNDI, JPA, JAXB, JSTL, J2EE Design Patterns, SOAP, and RESTful, Microservices Frameworks    : JSF, Spring Framework, NodeJS,  Hibernate Design Patterns    :  MVC,  DAO  Pattern,  Singleton  Pattern,  Front  Controller, Factory Pattern Messaging    : JMS, Apache Camel, ActiveMQ, RabbitMQ, Kafka, IBM MQ Database/Tools    :  Oracle,  IBM  DB2,  SQL  Server,  MySQL,  PostgreSQL, NOSQL, MongoDB, Cassandra. Web/App Server    : Apache Tomcat, WebLogic, IBM Web Sphere, JBoss, Kubernetes IDE/Tools    : Eclipse, NetBeans, WebLogic Workshop, IntelliJ, VS Code, PostMan, Splunk Version Control    : CVS, TFS, Subversion, Git, Bit Bucket, GitHub, GitLab, Clear Case, VSS, MS Visio Professional Experience:  Role: Sr Java Developer July 2024 - Till date Client: Goldman Sachs Responsibilities:   Responsible  for  all  stages  of  design,  development,  and  deployment  of applications. Active role in  Test Driven Development (TDD and BDD) apart from Agile Software Development.    Developed end to end data processing pipelines that begin with receiving data using  distributed  messaging  systems  Kafka  Implemented  application-level persistence using Hibernate and Spring.   Involved  in  detail  design  developing  use  cases,  use  case  diagrams,  class diagrams, sequence diagrams and high-level activity diagrams using UML from the requirements.   Implemented  features  like  Logging,  user  session  validation using  Spring-AOP module and Spring IOC.   Use of Splunk, Spring Boot Hibernate with Spring for creating RESTful Services and API s    Responsible  for  creating  and  maintaining  architecture for  Restful  API using Spring Boot.   Used Web Services (SOAP) for transmission of large blocks of XML data between two interfaces.   Involved in the process of data modeling Cassandra Schema.   Experienced  in designing  developing and  maintaining portal  java applications using IBM websphere portal on Rational Application Developer (RAD)   Created  Typescript reusable components and services to consume  REST API and developed test cases and performed unit test using JUnit Framework.   Implemented  data  validation  and  consistency  checks  through  PL/SQL  to  ensure regulatory compliance and accurate reporting.   Developed and maintained complex PL/SQL packages, procedures, and triggers to support critical real-time applications used in trading and post-trade operations   Analyzed  the  Maven dependency  management  in  the  base  code  to  annotate  the dependencies on to Spring Boot application into Gradle for Microservices.   Implemented API cont ...
#  {'candidate_id': '13777220638865',
#   'client_id': None,
#   'email': 'garlankiprameela@gmail.com',
#   'first_name': 'PRAMEELA',
#   'last_name': 'G',
#   'primary_role_code': None,
#   'current_role': None,
#   'skills': [],
#   'country': 'US',
#   'city': 'Dallas',
#   'address1': '',
#   'address2': '',
#   'workphone': '4696074298',
#   'homephone': '',
#   'cellphone': '4696074298',
#   'phone1': '',
#   'phone2': '4696074298',
#   'phone3': '4696074298',
#   'phone4': '',
#   'alternateemail': 'garlankiprameela@gmail.com   ',
#   'years_experience_total': 9.0,
#   'title_exp': [{'title': 'Role: Full Stack Java Developer May',
#     'exp': '01/2020 - 09/2022',
#     'months': 32},
#    {'title': 'Location: Chicago, Illinois Aug',
#     'exp': '01/2019 - 03/2020',
#     'months': 14},
#    {'title': 'Role: Java Developer Feb',
#     'exp': '01/2017 - 05/2019',
#     'months': 28},
#    {'title': 'Role: Junior Java Developer April',
#     'exp': '01/2015 - 11/2017',
#     'months': 34}],
#   'education': [{'SCHOOL': 'Jawaharlal Nehru Technological University',
#     'MAJOR': 'Jawaharlal Nehru Technological University',
#     'DEGREE': 'BE',
#     'YEAR': '2008'}],
#   'resume_data': "   Prameela arlanki    +1 (469) 607-4298    Education:  Bachelor's of Engineering, Jawaharlal Nehru Technological University-India (2008)      SUMMARY:  * Around 8+ years of professional work experience in Object Oriented Programming, design and development of Multi-tier distributed, Enterprise application using Java and J2EE technologies.  * Well versed with different phases of Software Development Life Cycle(SDLC) including Design, Implementation and Testing during the development of software development, Agile Methodology through Scrum, Test Driven Development, Waterfall.  * Experienced in web development applications using HTML5, CSS3, Javascript, Angular JS, React JS, Node JS, AJAX, JSON, XML, JQUERY, Bootstrap.  * ood Experience in developing single page applications using MEAN (Mongo db, Express, Angular, Node JS) stack.   * Experience in using React JS components, Forms, Events, Keys, Router, Redux, and Flux architecture.  * Developed microservices(API) using Spring Boot.  * Expert in core Java and implementing concepts like Multithreading, Concurrency, Exception Handling, File Handling, IO, enerics and Java Collections in various projects.  * Extensive experience using Java technologies: core Java, JDBC, Java Message Service, JSP, Servlets.  * Utilized Java 8 features like Lambda expressions and Stream API for bulk data operations on Collections.  * Hands on experience with Spring Framework  and associated technologies such as Spring MVC, Spring Data,  Spring Boot, Spring Security etc.  * Expert in developing web applications using MVC design patterns like Spring MVC and Struts 2 MVC.  * Experienced in Middleware persistence frameworks like Hibernate/JPA Entities for mapping Java classes using Hibernate Query Language(HQL), HSQL Named Queries, Criteria.  * Developed DAO objects and implemented data access layer using JPA-Hibernate to perform CRUD operations.  * Proficient in consuming and producing RESTful web services using Rest API and NodeJS.  * Experienced in implementing Service oriented architecture and Web Services using SOAP, RESTful.    * Expertise in DB-design, normalization, writing Triggers, Stores Procedures, Functions, Sequences, Cursors, Joins, Index Views, DDL, DML, User defined Data Types to implement business logic and maintain data integrity.  * Proficient in Relational DBMS like Oracle, SQL Server, MYSQL for performing SQL and PL/SQL programming and NoSQL DB like MongoDB.  * Experience with MongoDB development (reports, schema design, map reduce functions) and migrations from SQL relational databases to NoSQL databases.  * Hands-on experience in deploying applications using Jenkins.  * Experienced with build tools like ANT, Maven, radle and logging tools like Log4J.  * Experienced with testing tools like Junit, Jasmine and Karma.  * Experienced in using ithub, CVS for version control.  * Developed services using AWS EC2, S3 Buckets.  * Utilized AWS Lambda platform to upload data into AWS S3buckets and to trigger other Lambda functions focusing on high-availability, fault tolerance, and auto-scaling.  * Developed AWS cloud formation templates and setting up Auto scaling for EC2 instances and involved in the automated provisioning of AWS cloud environment using Jenkins.    TECHNICAL SKILLS:  Programming Languages  Java 1.17, SQL, PL/SQL.  Software Methodologies  Agile, Scrum, SDLC.  J2EETechnologies& frameworks  JSP , Servlets, JDBC, Java Beans XSD, JAX-RS, JAX-WS, Java Security.  Web Technologies  HTML, CSS, Bootstrap, JavaScript, JSON, Angular JS,  React JS, JSP, JQuery.  Frameworks  Spring 4.3, Hibernate 4.3, Spring Security 3.2, Spring MVC, Spring Boot, Spring Data, Spring Cloud, Servlets  Web Services  RESTful, SOAP  Design Patterns  Singleton, Data Transfer Object, Data Access Object, MVC.  IDEs  Eclipse, IntelliJ IDEA, Spring Tool Suite, Visual Studio.  Application/Web Servers  Web Logic Server 12c, Apache Tomcat (8.5/8.0), Apache HTTP   Server, IBM HTTP Server (8.5)  Relatio ...
#  {'candidate_id': '16460284648083',
#   'client_id': None,
#   'email': 'harthak19@gmail.com',
#   'first_name': 'Haritha',
#   'last_name': 'Koyineni',
#   'primary_role_code': None,
#   'current_role': None,
#   'skills': [],
#   'country': 'US',
#   'city': 'Plano',
#   'address1': '',
#   'address2': '',
#   'workphone': '',
#   'homephone': '6826013197',
#   'cellphone': '8722559068',
#   'phone1': '6826013197',
#   'phone2': '8722559068',
#   'phone3': '',
#   'phone4': '',
#   'alternateemail': 'haritha.official19@gmail.com',
#   'years_experience_total': 24.8,
#   'title_exp': [{'title': 'IDE & Tools\tVisual Studio), Visual Studio Code, SQL Server Management Studio (SSMS), SSRS, Power BI, Postman, Fiddler, Swagger, PL/SQL',
#     'exp': '01/2008 - 01/2022',
#     'months': 168},
#    {'title': 'Client: FEI Systems at Columbia, MD',
#     'exp': '01/2024 - 11/2025',
#     'months': 22},
#    {'title': 'Client: TIAA, Charlotte, NC',
#     'exp': '12/2021 - 12/2023',
#     'months': 24},
#    {'title': 'Client: UHG at Minneapolis, MN',
#     'exp': '09/2019 - 11/2021',
#     'months': 26},
#    {'title': 'Client: State of Michigan at Lansing, MI',
#     'exp': '05/2018 - 08/2019',
#     'months': 15},
#    {'title': 'Client: Verizon at Irving, TX',
#     'exp': '12/2016 - 04/2018',
#     'months': 16},
#    {'title': 'Client: ICICI Bank at Hyderabad, India',
#     'exp': '08/2014 - 10/2016',
#     'months': 26}],
#   'education': [{'SCHOOL': 'SASTRA deemed to be university',
#     'MAJOR': 'computer science',
#     'DEGREE': 'Bachelor',
#     'YEAR': '2014'}],
#   'resume_data': '                                                                                                         | 872-255-9068 | https://www.linkedin.com/in/harithak1122/ | Full Stack .NET Developer  Professional Summary: Over 10+ years of experience as a Full Stack .NET Developer involved in the complete SDLC including requirements gathering, design, development, testing, deployment, and support. Expertise in C#, .NET Core 6/5/3.1, ASP.NET MVC 5.2, Web API (REST & SOAP), Entity Framework (EF/Core), LINQ, ADO.NET, and VB.NET for backend development. Proficient in front-end development using Angular (9-16), React.js, TypeScript, JavaScript, HTML5, CSS3, Bootstrap, jQuery, and Telerik Kendo UI with Razor Pages. Experience in building responsive, cross-browser compatible UI components and using RxJS, NgRx, and reusable services with @Injectable in Angular. Built and deployed cloud-native microservices using Docker, integrated with CI/CD pipelines via Azure DevOps, GitHub Actions, TeamCity, and Octopus Deploy. Hands-on experience building Azure cloud-native applications using Function Apps, Durable Function Apps, Cosmos DB, Logic Apps, and Kafka for high-performance event-driven microservices and backend workflows.  Experience with OAuth2.0, JWT, SAML, and OpenID Connect for secure authentication and authorization across distributed systems. Strong in database development and optimization using SQL Server, Oracle, and MongoDB, including complex T-SQL, stored procedures, views, and indexing strategies. Integrated message-based communication with RabbitMQ and MSMQ for asynchronous event-driven microservices architecture and worked with Microsoft BizTalk for enterprise EDI data exchange. Hands-on experience with EDI X12 transaction sets such as 834, 835, and 837 for enrollment, claims processing, and payment remittance in health insurance systems.  Developed WPF and Silverlight applications using the MVVM pattern and built WinForms-based legacy systems with enhanced UX. Implemented SOA using WCF services with support for Serialization, Versioning, and Interoperability. Hands-on experience in unit testing and front-end testing using XUnit, NUnit, Jasmine, Karma, and validation with Postman and SoapUI. Authored project and technical documentation using SharePoint, contributed to knowledge bases, and maintained documentation for onboarding and support. Proficient in using Azure DevOps, TFS, GIT, GitHub, and Visual SourceSafe (VSS) for source control and Agile-based project tracking. Strong understanding of OOP concepts, SOLID principles, design patterns, and reusable architecture with class libraries and component-driven development. Familiar with mobile development techniques and implementing responsive designs for Android and iOS platforms.  Technical Skills: .NET Technologies  .NET 8, .NET 6/5/4.6/3.1, .NET Core, ASP.NET Core MVC 3/4/5.2, ASP.NET MVC 5, ASP.NET Web Forms, Razor Pages, Web Services, Windows Forms, ADO.NET, WCF, WPF, Silverlight, SOAP, SignalR, Blazor (Server/WebAssembly) Programming Languages  C#, VB.NET, JavaScript, TypeScript, SQL, PL/SQL, HTML5, CSS3, C, VB 5.0/6.0, JSON, XML Frontend Frameworks  AngularJS, Angular 9–16, React.js, Bootstrap, Kendo UI, jQuery, AJAX, D3.js, RxJS, NgRx Web Technologies HTML5, DHTML, CSS3, XML, JavaScript, Razor Views, ASP, IIS 5.0/6.0/7.0/10, RESTful APIs, JSON, MVC Architecture, SPA development ORM & Data Access Entity Framework 6/Core, Dapper ORM, ADO.NET, LINQ Databases SQL Server (2012/2014/2016/2019), Oracle 10g/11g/12c, MongoDB, PostgreSQL, MySQL, Azure SQL, Cosmos DB Cloud Platforms Microsoft Azure (App Services, Blob Storage, Functions, Key Vault, DevOps, App Configuration, Logic Apps), AWS (EC2, Lambda, S3, SNS, SQS, DynamoDB), OpenShift, PCF (Pivotal Cloud Foundry), Azure Kubernetes Service (AKS), Azure API Management DevOps & CI/CD Tools Azure DevOps, GitHub Actions, Jenkins, Maven, Gradle, TeamCity, Octopus Deploy, Build Master, Terraform, Docker, Kubernetes, He ...
#  {'candidate_id': '17301398855299',
#   'client_id': None,
#   'email': 'mohankumarp028@gmail.com',
#   'first_name': 'Mohan',
#   'last_name': 'Kumar',
#   'primary_role_code': None,
#   'current_role': None,
#   'skills': [],
#   'country': 'US',
#   'city': 'Tampa',
#   'address1': '',
#   'address2': '',
#   'workphone': '',
#   'homephone': '',
#   'cellphone': '9177739362',
#   'phone1': '',
#   'phone2': '9177739362',
#   'phone3': '',
#   'phone4': '',
#   'alternateemail': '',
#   'years_experience_total': 9.9,
#   'title_exp': [{'title': 'LexisNexis Risk Solutions',
#     'exp': '08/2025 - 12/2025',
#     'months': 4},
#    {'title': 'Bank of America, Tampa, FL',
#     'exp': '09/2022 - 07/2025',
#     'months': 34},
#    {'title': 'Mayo Clinic, Jacksonville, FL',
#     'exp': '11/2020 - 08/2022',
#     'months': 21},
#    {'title': 'UBS, New York, NY', 'exp': '01/2019 - 10/2020', 'months': 21},
#    {'title': "Lowe's, Mooresville, NC",
#     'exp': '05/2017 - 12/2018',
#     'months': 19},
#    {'title': 'Zensar Technologies, Bangalore, India',
#     'exp': '05/2015 - 01/2017',
#     'months': 20}],
#   'education': [{'SCHOOL': 'University of Central Missouri',
#     'MAJOR': 'Computer Science',
#     'DEGREE': 'Master',
#     'YEAR': '0'}],
#   'resume_data': "   (917) 773-9362 LinkedIn: https://www.linkedin.com/in/mohan-kumar-360360308/ Senior Software Engineer  Professional Summary: Senior Full Stack Java Developer with 8+ years of experience in designing, developing, and deploying high-performance, scalable, and secure enterprise applications. Expertise in Java (8/11/17), Spring Boot, Microservices, Angular, React, AWS, and DevOps, with hands-on experience across Monolithic, SOA, Microservices, N-Tier, and Event-driven architectures. Expertise in Spring ecosystem (Spring Boot, Spring MVC, Spring Security, Spring Batch, Spring Web Flux) and Hibernate/JPA for database interactions. Strong understanding of RESTful APIs and SOAP-based web services, with experience in Swagger/OpenAPI documentation.  Proficient in Java 17 advanced features, including sealed classes, pattern matching, and CompletableFuture API for concurrency improvements.  Extensive experience with Angular (9/15), React, Redux, TypeScript, JavaScript, and HTML5 for building dynamic, responsive web applications.  Developed secure, high-performance UI components and integrated front-end applications with REST APIs and WebSockets.  Hands-on experience with form validation, state management (NgRx, Redux), and performance optimization in Angular and React.  Hands-on experience in AWS (EC2, S3, RDS, Lambda, CloudWatch, DynamoDB) and Microsoft Azure for deploying cloud-based applications.  Implemented serverless architectures using AWS Lambda, API Gateway, and DynamoDB.  Expertise in CI/CD automation with Jenkins, GitLab, Docker, Kubernetes, and infrastructure automation using Terraform and Ansible.  Managed Kubernetes clusters to deploy and orchestrate containerized applications. Strong knowledge of relational (PostgreSQL, MySQL, Oracle 13c/11g, Microsoft SQL Server) and NoSQL databases (MongoDB, Cassandra, Redis, DynamoDB). Developed complex PL/SQL stored procedures, functions, triggers, and indexing strategies to enhance database performance. Implemented MongoDB Atlas for real-time analytics dashboards and optimized data aggregation using MongoDB BI Connector and Tableau.  Implemented OAuth 2.0, JWT, OIDC for securing RESTful APIs.  Integrated Spring Security for authentication and authorization in enterprise applications.  Experience with Apache Kafka, RabbitMQ, ActiveMQ, and JMS for real-time messaging and event-driven processing.  Experienced in designing and implementing real-time communication solutions by developing proof-of-concepts and production-ready integrations using WebSockets with Electron clients, enabling seamless push notifications and live data updates.  Proven ability to work across the full stack from Java/Spring Boot microservices to React/Electron frontends with hands-on expertise in cloud (AWS), DevOps, and secure, scalable application development. Developed Kafka stream processing pipelines to handle large-scale data ingestion into NoSQL stores like Cassandra.  Proficient in Test-Driven Development (TDD) and Behavior-Driven Development (BDD) using JUnit, Mockito, TestNG, Cucumber. Implemented centralized logging and monitoring using Splunk, ELK Stack (Elasticsearch, Logstash, Kibana), and Grafana.  Experienced in Agile methodologies (Scrum, Kanban, XP), participating in daily stand-ups, sprint planning, and retrospectives.  Used JIRA and Rally for tracking project progress, task management, and bug tracking.  Technical Skills: Programming Languages: Java (8/11/17), JavaScript, TypeScript, Angular, React, GraphQL  Backend & Frameworks: Spring (Boot, MVC, Security, Web Flux, Batch), Hibernate, REST/SOAP Web Services, Struts, Node.js, Express.js  Frontend & UI Development: Angular (9/15), React, Redux, HTML5, CSS3, Bootstrap, JSP, JSTL  Databases & ORM: PostgreSQL, MySQL, Oracle (PL/SQL), MongoDB, Cassandra, DynamoDB, Hibernate, Spring JPA  Cloud & DevOps: AWS (EC2, S3, RDS, Lambda, CloudWatch), Azure, PCF, Kubernetes, Docker, Jenkins, Git, GitHub, Bitbucket, Terraform, Ansible  Messa ...
#  {'candidate_id': '17618576578285',
#   'client_id': None,
#   'email': 'sahana.rsl1896@gmail.com',
#   'first_name': 'Sahana',
#   'last_name': 'Rajeshlal',
#   'primary_role_code': None,
#   'current_role': None,
#   'skills': [],
#   'country': 'US',
#   'city': 'Charlotte',
#   'address1': '1412 Blanche st',
#   'address2': '',
#   'workphone': '015',
#   'homephone': '',
#   'cellphone': '9515730258',
#   'phone1': '',
#   'phone2': '9515730258',
#   'phone3': '015',
#   'phone4': '',
#   'alternateemail': 'sraje015@ucr.edu',
#   'years_experience_total': 0.5,
#   'title_exp': [{'title': 'Asian Community Development Centre | Denver, Colorado',
#     'exp': '02/2025 - 05/2025',
#     'months': 3},
#    {'title': 'Around Me – AI Powered Social Networking Platform (Internship) | Los Angeles, California',
#     'exp': '06/2024 - 09/2024',
#     'months': 3}],
#   'education': [{'SCHOOL': 'University of California',
#     'MAJOR': 'Business Analytics',
#     'DEGREE': 'Master',
#     'YEAR': '2024'},
#    {'SCHOOL': 'The National Institute of Engineering',
#     'MAJOR': 'Information Science and Engineering C',
#     'DEGREE': 'BE',
#     'YEAR': '2021'}],
#   'resume_data': ' Rajesh Current Location: , NC Willing to work onsite in  , NC  ______________________________________________________Summary: Currently pursuing MS in Business Analytics (UCR), with specialization in Financial Analytics. 3+ years of experience in Business/Data Analytics, software deployments, and stakeholder engagement in Agile and cross-functional teams. Hands-on experience with release and deployment tools such as Jira, Confluence, and Power BI to support project tracking, coordination, and reporting. Successfully collaborated with QA, development, and support teams to manage and streamline release cycles, issue tracking, and documentation. Proficient in MS Office tools (Excel, Outlook, PowerPoint) for scheduling, release notes, and stakeholder communications. Strong understanding of change management processes and software delivery lifecycle (SDLC) across development, testing, and production environments. Excellent verbal and written communication skills; able to document technical procedures and communicate release updates to business and tech stakeholders. Skilled in SQL, Python, and data visualization to monitor deployment metrics and post-release performance.  Technical Skills:   Programming & Visualization: Python, SQL, R, VBA, Tableau, Power BI, Advanced Excel, Macros, Pandas, Matplotlib, Seaborn  Tools & Technologies: MySQL, Git, Hadoop, AWS Cloud, Azure DevOps, Jira, Looker, Adobe Analytics  Analytics: Data Wrangling, Data Manipulation, Data Modeling, Statistical Analysis, Time-Series Forecasting, Root-Cause Analysis, Reporting, Data Aggregation, KPIs, Data Storytelling, Data Warehousing, Requirements Elicitation, Agile/Scrum, Waterfall, SDLC, Six Sigma, Automation  ACADEMIC PROJECTS:  Semiconductor Market Data Analysis, UCR, A Sept 24-Dec 24   Designed an automated pipeline using Python (Pandas, Matplotlib, Seaborn) for cleaning and transforming raw semiconductor market data; and used Matplotlib & Seaborn for visualizing pricing trends, competitor benchmarks, and technology adoption rates.   Developed real-time analytics dashboard in Tableau to analyze market trends by automating reports & reducing data retrieval time by 50%.   E-cigarette Usage Analysis (Research-Based), UCR, A Apr 24-Jun 24   Conducted a research-based project analyzing data from 500 students to uncover key behavioral patterns using Python, revealing alcohol consumption and stress relief as significant predictors, mirroring incentive effective analysis.  Created predictive Machine Learning models using Random Forest and Neural Networks to identify influential factors and predict future usage patterns, achieving 93.5% accuracy in forecasting models ______________________________________________________  Education:  University of California - Riverside, California, United States Sep 23-Dec 24 Master of Science, Business Analytics; Minor: Financial Analytics (CGPA: 3.6/4)  The National Institute of Engineering, Karnataka, India Aug 17-Aug 21 Bachelor of Engineering, Information Science and Engineering (CGPA: 3.3/4) ______________________________________________________Professional Experience:   Asian Community Development Centre | Denver, Colorado                                                                              Feb 25 – Present Data Analyst - Project Lead  Collaborated with web and design teams to develop a data-informed consultation site for Vertex Assurance Client, using Google Analytics and SEO tools to track performance, user behavior, and conversion insights communicating the updates to the stakeholders.  Leveraged SQL and Excel to analyze user engagement trends and content consumption patterns, optimizing e-learning module flow and access logic for 100+ agents, resulting in a 20% improvement in completion rates. Led Trello-based project tracking and developed Power BI dashboards to visualize course engagement, quiz scores, and onboarding metrics enabling iterative improvements and stakeholder alignment.  Around M ...
#  {'candidate_id': '18114147674562',
#   'client_id': None,
#   'email': 'sasankn0907@gmail.com',
#   'first_name': 'Sasank',
#   'last_name': 'Nannapaneni',
#   'primary_role_code': None,
#   'current_role': None,
#   'skills': [],
#   'country': 'US',
#   'city': 'Brooklyn',
#   'address1': '',
#   'address2': '',
#   'workphone': '',
#   'homephone': '',
#   'cellphone': '6468547633',
#   'phone1': '',
#   'phone2': '6468547633',
#   'phone3': '',
#   'phone4': '',
#   'alternateemail': 'sasankndf@gmail.com',
#   'years_experience_total': 9.4,
#   'title_exp': [{'title': 'Goldman Sachs, NYC, NY',
#     'exp': '04/2023 - 09/2025',
#     'months': 29},
#    {'title': 'FedEx, Memphis, Tennessee',
#     'exp': '06/2021 - 03/2023',
#     'months': 21},
#    {'title': 'Elevance Health, Cincinnati, Ohio',
#     'exp': '12/2019 - 05/2021',
#     'months': 17},
#    {'title': 'Boeing, Arlington, Virginia',
#     'exp': '04/2018 - 11/2019',
#     'months': 19},
#    {'title': 'IBing Software Solutions Private Limited, Hyd, India',
#     'exp': '09/2015 - 12/2017',
#     'months': 27}],
#   'education': [{'SCHOOL': 'Velagapudi Siddartha Engineering College',
#     'MAJOR': 'Computer Science',
#     'DEGREE': 'Bachelor',
#     'YEAR': '2015'}],
#   'resume_data': "Candidate Submittal Cover Page  Candidate Name:   Phone Number: (646) 854-7633 Email Address:  Current location: , NY, 11213 Willing to Relocate?  Yes Former TCS employee / contractor?  (Please specify employment type and when) No Interview Availability  (Dates listed must be 48-72 hours after candidate submission) INCLUDE TIMEZONE Time Slot 1 (Date / Time) Time Slot 2 (Date / Time) Time Slot 3 (Date / Time) Availability for Friday (09/19/2025) 10 AM to 4 PM EST Availability for Monday (09/22/2025) 10 AM to 4 PM EST Availability for Tuesday (09/23/2025) 10 AM to 4 PM EST Availability to Start:  2 weeks after getting offer. Relevant Skills  Mandatory Skills (As listed in JD) # of Years Experience Candidate s relevant hands-on  experience  Java 9+ Having More than 9+ Years  ADK 8+ Having more than 8+ years  LangGraph 8+ Having more than 8+ years  Python 9+ Having more than 9+ years       Professional Summary Around 9+ years of experience in all stages of the Software Development Life Cycle (SDLC) such as Application Specifications, Design, Development, Testing, Debugging and Maintenance.  Developed UI modules using Angular 7/9/10/11, Node.JS, Java Script, jQuery, Ajax, validations using Ajax in Node.JS, AngularJS, Angular11 and dash board's reports using Backbone.js.  Experience in Angular11 along with Bootstrap, CSS3 to create reusable components for RWD apps. Implemented graph-based dependency mapping for trade reconciliation using LangGraph. Experience in implementing Component life cycle architecture, store actions, using socket.io in React-Redux app to handle real time data, installing React Router, Thunk Redux for API calls in React JS.  Experience with HTML5, XML, XHTML, DHTML, CSS3, Tiles, Tag Libraries and JSON. Designed graph-based dependency tracking for inventory flows using LangGraph.  Designed custom adapters using ADK for secure communication with third-party banking platforms. Created ADK-based connectors for integration with third-party logistics APIs. Proficient in applying design patterns like MVC, Singleton, Adapter, Bridge, Session Facade, Service Locator, Visitor, Observer, Decorator, Front Controller, Data Access Object.  Proficient in implementation of frameworks like Spring (Spring MVC, IOC, JDBC, Spring Boot, Spring REST, Spring Micro services), AJAX frameworks (Rich Faces, My Faces) and ORM frameworks like Hibernate, Spring DAO, Java Data Objects and Enterprise Java Beans Entity Beans.  Hands-on experience in Linux-based systems for development, deployment, and troubleshooting across various environments. Experienced with AWS CloudFormation for defining, provisioning, and managing cloud resources Expertise in Micro services developing SOA (Service Oriented Architecture) and J2EE Web Services based on SOAP, WSDL, UDDI, JAX-WS, JAXB, JAX-RPC using tools like Apache Axis.  Created Micro Services using Spring Boot and deployed on AWS instances like EC2.  Developed automation tools and utilities using Visual Basic for Applications (VBA) to support internal finance workflows and reporting tools, streamlining data processing for traders and middle-office teams. Hands-on expertise with MySQL (relational) and MongoDB (NoSQL) for scalable data storage and retrieval Having good implementation experience with installation and configuration of Kubernetes, clustering them and managed local deployments in Kubernetes, provided consistent environment using Kubernetes for deployment scaling and load balancing to the application from development through production.  Proficient in designing and implementing integration processes using Apache Camel for seamless data propagation and integration across cloud environments. Skilled in using Jenkins, Docker, and JFrog for CI/CD, handling deployment pipelines, versioning, and maintaining code repositories. Expertise with employment of Spring Kafka and Zookeeper apart from JMS as Messaging Service.  Experienced in designing and developing Enterprise and Web-base ...
#  {'candidate_id': '18121606064589',
#   'client_id': None,
#   'email': 'andrew.p.darwin@gmail.com',
#   'first_name': 'Andrew',
#   'last_name': 'Darwin',
#   'primary_role_code': None,
#   'current_role': None,
#   'skills': [],
#   'country': 'US',
#   'city': 'Chattanooga',
#   'address1': '',
#   'address2': '',
#   'workphone': '',
#   'homephone': '',
#   'cellphone': '8722030812',
#   'phone1': '',
#   'phone2': '8722030812',
#   'phone3': '',
#   'phone4': '',
#   'alternateemail': 'nfo-tlh-ykm@mail.dice.com',
#   'years_experience_total': 11.8,
#   'title_exp': [{'title': 'Ferguson Enterprise Inc | Los Angeles, CA',
#     'exp': '12/2024 - 09/2025',
#     'months': 9},
#    {'title': 'HCA Healthcare | Nashville, TN, USA',
#     'exp': '09/2017 - 11/2024',
#     'months': 86},
#    {'title': 'Fiserv | Milwaukee, WI, USA',
#     'exp': '04/2015 - 07/2017',
#     'months': 27},
#    {'title': 'IRIS Networks | Nashville, TN, USA',
#     'exp': '06/2013 - 02/2015',
#     'months': 20}],
#   'education': [{'SCHOOL': 'State University of New York at Oswego SUNY Oswego',
#     'MAJOR': 'Software Engineering',
#     'DEGREE': 'BS',
#     'YEAR': '2013'}],
#   'resume_data': '  Senior Java Engineer    +1 (872) 203-0812       , TN  PROFILE  As a Java Full Stack Engineer with over 12 years of experience, I specialize in designing and implementing comprehensive solutions that contribute to business growth. My core expertise includes Java, Spring Framework, and creating RESTful APIs for seamless system integration. I am proficient in modern frontend technologies such as Angular, React, and Vue.js, utilizing TypeScript and JavaScript to build engaging user interfaces. With extensive experience in database management, I focus on building scalable and high-performance applications. My background includes significant projects in healthcare and financial sectors, where I have demonstrated strong cloud experience with Azure and AWS. By incorporating cloud solutions, I build, deploy, manage, and optimize applications effectively. This expertise supports the creation of scalable, reliable cloud-based applications that align with modern software development practices. I thrive in collaborative Agile teams, mentor junior developers, and continuously advance my technical skills to stay ahead of industry trends. EDUCATION  Bachelor of Science in Software Engineering                                            08/2009 – 05/2013 | Oswego, NY State University of New York at Oswego (SUNY Oswego)  PROFESSIONAL EXPERIENCE  Sr. Software Engineer Ferguson Enterprise Inc.                                                                          12/2024 – Present | Los Angeles, CA At Ferguson Enterprises, I led the end-to-end development of the Automated Supply Program (ASP), a proprietary, cloud-native MRO platform designed to streamline procurement, asset management, preventive maintenance, and vendor-managed inventory processes for enterprise clients. I architected and implemented modular Java-based microservices using Spring Boot 3, RESTful APIs, and event-driven design patterns, ensuring high scalability, interoperability, and security. My work spanned microservices orchestration on Azure Kubernetes Service (AKS), third-party integrations via SOAP/REST, and secure API communication using OAuth 2.0, JWT, and Azure Key Vault, while driving modernization efforts for Ferguson s legacy ERP systems. Automated Supply Program (ASP) – Enterprise MRO Platform   Architected and developed a distributed microservices ecosystem using Java, Spring Boot 3, Spring Cloud, RESTful APIs, and MongoDB, enabling scalable, fault-tolerant workflows for e-requisitioning, asset and warranty tracking, preventive maintenance scheduling, and vendor-managed inventory.   Designed, containerized, and deployed services to AKS with Docker, implementing automated scaling, rolling updates, and self-healing clusters for high availability across staging and production environments.   Integrated legacy and modern systems via SOAP and REST endpoints, using Spring Web Services and Spring Integration to ensure backward compatibility with ERP modules and vendor systems.   Developed asynchronous messaging and orchestration flows using Azure Service Bus and Spring Cloud Gateway, enabling real-time data routing, transformation, and event-driven triggers across platform modules.   Implemented enterprise-grade security with OAuth 2.0, JWT-based authorization, and Azure Key Vault for secret management, ensuring compliance with corporate governance and security policies.   Automated infrastructure provisioning with Terraform and built Azure DevOps CI/CD pipelines integrating SonarQube, unit/integration testing, and multi-environment deployments, reducing manual intervention and improving release velocity.   Designed high-performance data models in MongoDB, Azure SQL, and PostgreSQL, optimizing queries, adding indexing strategies, and improving concurrent transaction performance under high load.   Built and maintained middleware for hybrid JSON/XML API responses using Jackson, Spring Data REST, and Swagger/OpenAPI, ensuring compatibility with multiple cl ...
#  {'candidate_id': '18161309884041',
#   'client_id': None,
#   'email': 'pradeeppal0414@gmail.com',
#   'first_name': 'Pradeep',
#   'last_name': 'Pal',
#   'primary_role_code': None,
#   'current_role': None,
#   'skills': [],
#   'country': 'US',
#   'city': 'Chicago',
#   'address1': '501 E 32nd Street',
#   'address2': '',
#   'workphone': '',
#   'homephone': '',
#   'cellphone': '3123806379',
#   'phone1': '',
#   'phone2': '3123806379',
#   'phone3': '',
#   'phone4': '',
#   'alternateemail': '',
#   'years_experience_total': 3.5,
#   'title_exp': [{'title': 'Software Developer - Criterion Business Services, Richmond, Texas',
#     'exp': '08/2024 - 04/2025',
#     'months': 8},
#    {'title': 'Software Development Intern ',
#     'exp': '06/2023 - 12/2023',
#     'months': 6},
#    {'title': 'Software Developer', 'exp': '08/2020 - 07/2022', 'months': 23},
#    {'title': 'Software Developer Intern ',
#     'exp': '02/2020 - 07/2020',
#     'months': 5}],
#   'education': [{'SCHOOL': 'Illinois Institute of Technology',
#     'MAJOR': 'Computer Science',
#     'DEGREE': 'Master',
#     'YEAR': '2024'},
#    {'SCHOOL': 'Thakur College of Engineering and Technology',
#     'MAJOR': 'Computer Engineering',
#     'DEGREE': "Bachelor's",
#     'YEAR': '2021'}],
#   'resume_data': ' PRADEEP PAL  Software Engineer  , IL | +1 (312) 380-6379 |  |LinkedIn | GitHub    SUMMARY                   Software Engineer with 3+ years of experience in full-stack development, data integration, and cloud solutions, proficient in Java, Python, Bash, SQL, TypeScript, and JavaScript for scalable applications. Experienced with AWS, GCP, RESTful APIs, and DevOps tools such as Docker and Kubernetes, skilled in creating efficient, secure, and data-driven applications for enhanced operational performance.  EDUCATION                   Master of Science in Computer Science                      Aug 2022 - May 2024   Illinois Institute of Technology - , Illinois  Courses: Object Oriented Programming, Advanced Database Management, Big Data and Technologies, Software Testing and Analysis     Bachelor of Engineering in Computer Engineering                                     Aug 2017 - May 2021   Thakur College of Engineering and Technology - Mumbai, India  Courses: Data Structures and Algorithms, Cloud Computing, Operating Systems, Natural Language Processing, Computer Networks, Artificial Intelligence     PROFESSIONAL EXPERIENCE                   Software Developer - Criterion Business Services, Richmond, Texas                      Aug 2024 - Present    Built a finance and tax management platform leveraging Java, JavaScript, and SQL, automating workflows and increasing data accuracy by 25%.    Designed RESTful APIs within a Node.js and AWS environment to facilitate seamless frontend and backend connectivity, ensuring real-time data synchronization and enhancing application responsiveness across cloud-hosted services.    Optimized PostgreSQL database architecture within Spring Boot applications, enhancing query performance by 50% and streamlining data retrieval through CI/CD automation for more reliable deployments.    Defined project requirements with cross-functional teams using JIRA and Agile methodologies, accelerating project turnaround time by 20%.  Software Development Intern - Leap of Faith Technologies, Libertyville, IL                       Jun 2023 - Dec 2023    Programmed a Python and Django application integrated with an EMR system using FHIR and HL7 standards, ensuring secure patient data handling and efficient scheduling.    Developed a HIPAA-compliant health report service on AWS (Lambda, S3, IAM), automating data retrieval and reducing manual processing by 30%. Structured access controls and conducted data audits, maintaining compliance and bolstering data security measures.    Streamlined data management by implementing RESTful APIs and integrating them with PostgreSQL database, resulting in more efficient data handling.    Created a cross-platform application with Flutter and Dart, enabling greater accessibility and usability across multiple devices.  Software Developer - Adani, India                       Aug 2020 - Jul 2022    Improved backend system performance and scalability by implementing Java and Spring Boot-based solutions, optimizing API response times and overall user experience.    Utilized Python to develop robust backend components for enterprise-level applications, ensuring high performance and maintainability.    Established a real-time data pipeline using AWS S3, Redshift, and SQL, automating key workflows for inventory management and increasing reporting efficiency by 25%.    Planned end-to-end data pipelines for ingestion, model training, and deployment, enabling efficient scaling of machine learning (ML) solutions across cloud-based environments.    Integrated New Relic for real-time application performance monitoring and alerting, enabling proactive incident management and reducing mean time to resolution (MTTR) by 35%.    Strengthened security protocols with Spring Security, OAuth, and AWS IAM, cutting unauthorized access incidents by 30%.    Reduced production issues by 20% through integration testing, rapid change request handling, code reviews, and swift bug resolution.     ...
#  {'candidate_id': '18467450198989',
#   'client_id': None,
#   'email': 'ravirequestinfo4@gmail.com',
#   'first_name': 'Ravi',
#   'last_name': 'b',
#   'primary_role_code': None,
#   'current_role': None,
#   'skills': [],
#   'country': 'US',
#   'city': 'Dallas',
#   'address1': '',
#   'address2': '',
#   'workphone': '',
#   'homephone': '',
#   'cellphone': '2145001560',
#   'phone1': '',
# ...
#  {'candidate_id': '17754887086885',
#   'client_id': None,
#   'email': 'madhavajava08@gmail.com',
#   'first_name': 'Madhava Sai',
#   'last_name': 'Y',
#   'primary_role_code': None,
#   'current_role': None,
#   'skills': [],
#   'country': 'US',
#   'city': 'Chicago',
#   'address1': 'Chicago',
#   'address2': '',
#   'workphone': '',
#   'homephone': '',
#   'cellphone': '3124690473',
#   'phone1': '',
#   'phone2': '3124690473',
#   'phone3': '',
#   'phone4': '',
#   'alternateemail': '',
#   'years_experience_total': 5.6,
#   'title_exp': [{'title': 'Client: YchartsFinancial Services',
#     'exp': '02/2024 - 04/2025',
#     'months': 14},
#    {'title': 'Client: Options Clearing corporationFinancial Services',
#     'exp': '10/2021 - 02/2024',
#     'months': 28},
#    {'title': 'Client: Credit Acceptance Corporation, Chicago, IL Financial Services',
#     'exp': '09/2020 - 10/2021',
#     'months': 13},
#    {'title': 'Client: University of Illinois at Chicago, Chicago, IL',
#     'exp': '09/2019 - 09/2020',
#     'months': 12}],
#   'education': [{'SCHOOL': 'University of Illinois at Chicago',
#     'MAJOR': 'Computer Science',
#     'DEGREE': 'BS',
#     'YEAR': '0'}],
#   'resume_data': "    JAVA FULL STACK DEVELOPER                                                                                +1 (312)-469-0473  Professional Summary:  5+ years of experience in requirement gathering designing, developing, and deploying web-based applications, enhancing user experience and operational efficiency. Proficient in Object-Oriented Analysis and Design (OOAD) using UML, with a solid foundation in Agile development methodologies. Expertise in full-stack development using HTML5, CSS3, JavaScript, AngularJS, Java, J2EE, Spring Framework (including Spring MVC, Spring Boot, Spring Cloud), and Hibernate ORM Leveraged front-end technologies including CSS3, jQuery, and Bootstrap to develop highly interactive, responsive web interfaces. Skilled in architecting and developing applications with Angular JS and React JS, significantly improving interface responsiveness and user engagement. Developed Single Page Applications (SPA) using Angular 12/14, enhancing application performance and user interaction. Integrated RESTful web services using Java 8 and Spring MVC with MongoDB, streamlining data exchange and application functionality. Demonstrated mastery in implementing MVC architecture and design patterns such as Singleton, Factory, and DAO to create scalable and maintainable codebases. Extensive experience in multi-tier application development using technologies like XML, Web Services REST, HTML5, JavaScript, and Ajax. Conducted comprehensive code reviews and applied best Java programming practices to enhance application reliability and maintainability. Utilized core Java APIs for building multi-threaded server-side components, improving application performance for large-scale systems. Skilled in using IDE tools like Eclipse for efficient development of JSPs, Servlets, and other Java/J2EE components. Adept at developing and maintaining web services using REST APIs, enabling seamless data integration across platforms. Designed and created Micro Services business segments and RESTful administration endpoints utilizing Spring boot. Experience using Hibernate for mapping Java classes with database and using Criteria API and Hibernate Query Language (HQL). Experience in making SOAP based Web Services using Apache CXF, JAX-WS and RESTful organizations like JAX-RS. Applied proficiency in Test Driven Development (TDD) using Selenium WebDriver, TestNG, and JUnit to ensure robust, error-free code. Hands on experience with SQL/No SQL databases systems like Oracle, MySQL, MongoDB. Experienced with Agile tools such as Jira and Confluence, facilitating effective team collaboration and project management. Implemented CI/CD pipelines to improve software delivery processes and maintain high deployment standards. Proficient with AWS cloud services, including RDS, EC2, S3, Amazon EBS, Amazon VPC, Amazon Redshift, Amazon EMR, Amazon SQS and Lambda, optimizing deployment and scalability while reducing costs Hands on experience on Operating Systems like Ubuntu, Linux, and Windows. Strong analytical and troubleshooting skills, with a track record of diagnosing and resolving complex technical issues promptly.  Technical Skills Languages  Java, J2EE Enterprise Java Java, J2EE, Spring, JSP, Servlet, JDBC, JSF, JPA Mark-up/XML Technologies HTML5, CSS3, JavaScript, jQuery, Angular JS, Node JS, Express.js XML, AJAX, JSON Tools & Framework Spring Boot, Spring, Spring Reactive, Spring MVC, JUnit Web services RESTful Web/App Servers Web Sphere, Apache Tomcat, JBoss Database Oracle, SQL-Server, MySQL server, Mongo DB Data Streaming Kafka, ActiveMQ Development Tools Eclipse, Spring Tool Suite (STS), Net Beans, IntelliJ, Visual-studio, Sublime Testing Tools/ Others JUnit, Selenium Version Control GIT OS & Environment Windows, LINUX, UNIX Design Patterns MVC, Front Controller, Singleton, Business Delegate and DAO patterns Cloud/CI-CD AWS, Jenkins, Docker, Kubernetes   Certification AWS Cloud Practitioner Essentials  Professional Experience  Clie ...
#  {'candidate_id': '14657248940043',
#   'client_id': None,
#   'email': 'bala.sudheer26@gmail.com',
#   'first_name': 'Bala Sudheer',
#   'last_name': 'Ummaneni',
#   'primary_role_code': None,
#   'current_role': None,
#   'skills': [],
#   'country': 'US',
#   'city': 'Irving',
#   'address1': '',
#   'address2': '',
#   'workphone': '',
#   'homephone': '',
#   'cellphone': '6824120216',
#   'phone1': '',
#   'phone2': '6824120216',
#   'phone3': '',
#   'phone4': '',
#   'alternateemail': '',
#   'years_experience_total': 7.3,
#   'title_exp': [{'title': 'CLIENT: PNC Financial Services, TX',
#     'exp': '05/2024 - 09/2025',
#     'months': 16},
#    {'title': 'CLIENT: IBM/UPS, NJ', 'exp': '01/2023 - 02/2024', 'months': 13},
#    {'title': 'CLIENT: Bed Bath and Beyond, NJ',
#     'exp': '10/2021 - 12/2022',
#     'months': 14},
#    {'title': 'CLIENT: Tower Semiconductors Inc, Newport Beach, CA',
#     'exp': '08/2020 - 09/2021',
#     'months': 13},
#    {'title': 'CLIENT: SAP Labs, Karnataka, India',
#     'exp': '09/2017 - 05/2020',
#     'months': 32}],
#   'education': [{'SCHOOL': 'University of Texas in Information Systems',
#     'MAJOR': '',
#     'DEGREE': 'Master',
#     'YEAR': '2024'}],
#   'resume_data': "                                                                           SUMMARY:    Having 8 years of experience as a Java Developer in the IT industry. Extensively experienced in Software Analysis, Design, Development, Implementation and Testing of Object-Oriented Applications and Web based Enterprise Applications using Java/J2EE.   Proficient in UI design, developed front end using JSP, HTML5, CSS3, JavaScript, Ajax, jQuery, AngularJS, Angular 2/6/9, NodeJS and ReactJs.   Well experienced in view rendering using jQuery, React JS and implementing React JS with Redux pattern to attain MVC functionality.   Worked with a backend service environment using NodeJS and can install and manage modules using Node Package Manager (NPM).   Experience in building isomorphic applications using React.js and Redux with GraphQL on server side.   Extensive knowledge on the Spring Modules like Spring IOC and Dependency Injection, Spring MVC, Spring Batch, Spring Security (Authentication and Authorization), Spring AOP for Code Modularity and Spring Boot.   Involved in designed fully distributed systems with the use of Restful API and Microservices.   Experience in implementing Service Oriented Architectures (SOA) using XML based Web Service such as SOAP.   Developed and deployed Microservices based applications using Spring Boot and NodeJs with Express.   Experience with handling Kafka streams by consuming from topics and producing to topics.   Experienced with RDBMS implementation and development using Oracle and My SQL.   Experience in Importing data from various sources to the Cassandra cluster using Java API s.   Expertise in database modeling and development using No SQL Database such as MongoDB.   Experienced in using cloud-based AWS development and deployment using EC2, ECS, ALB, S3, Lambda, EBS, EFS, CloudWatch, Elasticsearch, Route53, VPC.   Well experienced with building tools like Gradle and Webpack.   Experienced with the build tool Maven, Gradle and continuous integration tools like Jenkins and Kubernetes for Continuous Delivery.    Experience in Integration of Amazon Web Services (AWS) with other applications infrastructure.   Deployed applications on GCP, OpenShift and Azure Cloud Platform.    Good experience in J2EE Testing in developing test cases with Junit, MOCKITO for Unit testing, and logging using Log4j.    Worked on various testing frameworks for front end/user interface like Jasmine, and Selenium.   Experience in using tools like Ant and Maven for build automation.   Professional experience in integrated development tools (IDEs) like Eclipse, NetBeans, IntelliJ, and Visual Studio Code. Worked extensively with version control tools like GitHub, SVN, Bitbucket and bug tracking tools like Rally and JIRA.   Good experience in using Software development methodologies like Agile (Scrum) methodologies.  TECHNICAL SKILLS: Programming Languages  Java, J2EE, SQL, JavaScript, Groovy Web Technologies  HTML5, CSS, JavaScript, AJAX, JSON, Bootstrap, jQuery, Angular, React.js, Redux, NodeJS, XML, SOAP, REST. J2EE Technologies & Frameworks Servlets, JSP, JDBC, SOAP, REST, XML, Spring, Hibernate, Spring MVC, Spring Boot, Spring Data, Spring Batch, Spring Security, GraphQL. Databases    Oracle Sql, PostgreSQL, MYSQL, MongoDB, DynamoDB, Cassandra Web Service Frameworks  AWS, Microservices Web/App Servers   Apache Tomcat Build & Configuration Tools  Maven, Gradle, Ant, Webpack, NPM, Jenkins, Log4j Testing Tools    Junit, Mockito, Cucumber, Jasmine, Karma, Selenium, Appium, Groovy Version Control    GIT, SVN Cloud Technologies   AWS, EC2, EBS, S3, Docker, ECS, S3, Lambda, EFS Operating System   Windows, Linux, Unix, MAC IDE s     Eclipse, Visual Studio, IntelliJ IDEA, Spring Tool Suite Devops Tools And methodologies: AWS, Azure, ECS, Jenkins, CI/CD pipelines, OpenShift, Kubernetes.  PROFESSIONAL EXPERIENCE:  CLIENT: PNC Financial Services, TX                                                                           May 20 ...
#  {'candidate_id': '18459439582599',
#   'client_id': None,
#   'email': 'vinodkputtamadegowda@gmail.com',
#   'first_name': 'Vinod',
#   'last_name': 'Kumar',
#   'primary_role_code': None,
#   'current_role': None,
#   'skills': [],
#   'country': 'US',
#   'city': 'Mountain View',
#   'address1': '',
#   'address2': '',
#   'workphone': '',
#   'homephone': '',
#   'cellphone': '3139194178',
#   'phone1': '',
#   'phone2': '3139194178',
#   'phone3': '',
#   'phone4': '',
#   'alternateemail': '',
#   'years_experience_total': 4.2,
#   'title_exp': [{'title': 'Full Stack Developer - UT Arlington, TX',
#     'exp': '11/2024 - 05/2025',
#     'months': 6},
#    {'title': 'Software Engineer - NTT DATA',
#     'exp': '08/2020 - 07/2022',
#     'months': 23},
#    {'title': 'Junior Software Engineer - Accenture',
#     'exp': '11/2018 - 08/2020',
#     'months': 21}],
#   'education': [{'SCHOOL': 'The University of Texas at Arlington',
#     'MAJOR': 'Computer Science',
#     'DEGREE': 'Master',
#     'YEAR': '2024'},
#    {'SCHOOL': 'Visvesvaraya Technological University',
#     'MAJOR': 'Visvesvaraya Technological University',
#     'DEGREE': 'BE',
#     'YEAR': '2018'}],
#   'resume_data': '   313-919-4178 |  | linkedin.com/in/vinodpgowda | vinodpgowda.github.io/portfolio  SUMMARY _____________________________________________________________________  Full Stack Software Developer with a Master s in Computer Science and 4+ years of experience building secure,  scalable applications using Java, Spring Boot, JavaScript, and SQL in microservices architecture. Skilled in  developing responsive user interfaces with React and TypeScript. Proficient in performance optimization  through SQL query tuning, test-driven development, code refactoring, and production debugging. Adept at  collaborating with cross-functional teams in Agile environments to deliver high-quality software.  SKILLS _____________________________________________________________________  Backend Development:   Java, Spring Boot, Spring Data JPA, Spring Security, Hibernate, Kafka, Python  Frontend Development: React, Redux, JavaScript, TypeScript, Angular, Jest, GraphQL, HTML, CSS  Database Management:  SQL, PostgreSQL, MySQL, Oracle DB, MongoDB, Redis, Data Modeling  Cloud and DevOps:           AWS (S3, RDS, Lambda, CloudWatch), Docker, Kubernetes, Jenkins, Maven  Tools & Technologies:     JUnit, Mockito, Git, GitHub, Postman, IntelliJ, Jira, Agile, Scrum, Linux  EXPERIENCE _____________________________________________________________________  Full Stack Developer     UT Arlington, TX                                                                Nov 2024 - Present                                                                                                           Designed RESTful web services in Java and Spring MVC for a scalable hackathon platform serving 5K+ users.    Built React components using hooks, Redux state management, and async fetch for real-time event tracking.    Improved frontend reliability by 30% through consistent API error handling and form validation in React.    Tested frontend components with Jest and React Testing Library to ensure UI correctness and stability.    Automated scoring and leaderboard workflows through clean API contracts and scheduled Spring Boot tasks.  Software Engineer     NTT DATA                                                                           Aug 2020 - July 2022                                                                                                                   Designed REST APIs for transaction processing and notification delivery in a core banking system built on  event-driven microservices architecture using Java, Spring Boot, TypeScript, Kafka, and PostgreSQL.    Improved PostgreSQL query performance by 40% on transaction APIs using read replicas and indexing.    Developed a TypeScript UI interface to display transaction statuses and notifications from Kafka events.    Built Kafka producers in transaction services to emit payment and status events for downstream processing.    Implemented Kafka consumers with offset tracking to trigger real-time notifications from transaction events.    Secured REST APIs with Spring Security and JWT auth, including token validation and session management.    Deployed containerized services to AWS ECS (EC2) with Docker and ECR, automating CI/CD using Jenkins.    Monitored service health and logs using Spring Boot Actuator and Splunk to support production debugging.  Junior Software Engineer     Accenture                                                                         Nov 2018 - Aug 2020                                                                                                                                                         Engineered a secure operations management application using Java, Spring Boot, and JavaScript to process  and serve production data from 12 AIRB aircraft workflows, improving scheduling efficiency by 40%.    Designed a PostgreSQL schema with weekly partitions and indexing to optimize query performance.    Built a React dashboard to visualize KPI trends with filters and time ranges for optim ...
